# %% [markdown]
# Menu driven programmes

# %%
# Create an empty list to store names
namelist = []

# Define a function to store a name in the list
def storeName():
    # Prompt the user to enter a name and store it in the 'name' variable
    name = input("Enter the name")
    # Remove leading and trailing whitespace and convert the name to title case
    name = name.strip().title()
    # Append the formatted name to the 'namelist' list
    namelist.append(name)
    # Return the formatted name (not used in the current code)
    return name

# Define a function to list all the names in 'namelist'
def listNames():
    # Print a line of asterisks for visual separation
    print("*"*30)
    print("Names in the list")
    print("*"*30)
    # Iterate through each name in 'namelist' and print it
    for name in namelist:
        print(name)
    # Print another line of asterisks for visual separation
    print("*"*30)

# Define a function to search for a name in 'namelist'
def searchName():
    # Splitting 'search' variable (which is undefined) doesn't make sense
    # It's better to get the search query as input from the user
    search = input("Enter the name to search: ").strip().title()
    # Iterate through each name in 'namelist' and check if it matches the search query
    for name in namelist:
        if name == search:
            # If a match is found, print a message
            print("Name exists in the list")

# Create an infinite loop for the menu
while True:
    print("*"*30)
    print("1. Enter the names")
    print("2. List the names")
    print("3. Search for a Name")
    print("4. Exit")
    print("*"*30)

    # Prompt the user for their choice and convert it to an integer
    choice = int(input("Enter your Choice ?"))
    print("You have entered choice", choice)
    
    # Check the user's choice and perform the corresponding action
    if choice == 1:
        # Call the 'storeName' function to add a name to the list
        name = storeName()
        print("Name {} added successfully".format(name))
    elif choice == 2:
        # Call the 'listNames' function to list all the names
        listNames()
    elif choice == 3:
        # Call the 'searchName' function to search for a name
        searchName()
    elif choice == 4:
        # Exit the program
        break
       
    else:
        # If an invalid choice is entered, print an error message
        print("Invalid Syntax")
# Out:
# ******************************
# 1. Enter the names
# 2. List the names
# 3. Search for a Name
# 4. Exit
# ******************************
# You have entered choice 4

# %%
# Create an empty list to store names
namelist = []

# Define a function to store a name in the list
def storeName():
    # Prompt the user to enter a name and store it in the 'name' variable
    name = input("Enter the name")
    # Remove leading and trailing whitespace and convert the name to title case
    name = name.strip().title()
    # Append the formatted name to the 'namelist' list
    namelist.append(name)
    # Return the formatted name (not used in the current code)
    return name

# Define a function to list all the names in 'namelist'
def listNames():
    # Print a line of asterisks for visual separation
    print("*"*30)
    print("Names in the list")
    print("*"*30)
    # Iterate through each name in 'namelist' and print it
    for name in namelist:
        print(name)
    # Print another line of asterisks for visual separation
    print("*"*30)

# Define a function to search for a name in 'namelist'
def searchName():
    search = search.strip().title()
    found = False 
    for name in namelist:
        if name == search:
            found = True
            break
    if found == True:    
        print("Name exists in the list")
    else:
        print("Name does not exist in the list")

# Create an infinite loop for the menu
while True:
    print("*"*30)
    print("1. Enter the names")
    print("2. List the names")
    print("3. Search for a Name")
    print("4. Exit")
    print("*"*30)

    # Prompt the user for their choice and convert it to an integer
    choice = int(input("Enter your Choice ?"))
    print("You have entered choice", choice)
    
    # Check the user's choice and perform the corresponding action
    if choice == 1:
        # Call the 'storeName' function to add a name to the list
        name = storeName()
        print("Name {} added successfully".format(name))
    elif choice == 2:
        # Call the 'listNames' function to list all the names
        listNames()
    elif choice == 3:
        # Call the 'searchName' function to search for a name
        searchName()
    elif choice == 4:
        # Exit the program
        break
       
    else:
        # If an invalid choice is entered, print an error message
        print("Invalid Syntax")
# Out:
# ******************************
# 1. Enter the names
# 2. List the names
# 3. Search for a Name
# 4. Exit
# ******************************
# You have entered choice 1
# Name Leran added successfully
# ******************************
# 1. Enter the names
# 2. List the names
# 3. Search for a Name
# 4. Exit
# ******************************
# You have entered choice 2
# ******************************
# Names in the list
# ******************************
# Leran
# ******************************
# ******************************
# 1. Enter the names
# 2. List the names
# 3. Search for a Name
# 4. Exit
# ******************************
# You have entered choice 4

# %% [markdown]
# QQ: create a menu driven programme using dictionaries to store the following:
# details of students
#     name:
#     Reg.No.:
#     Phone:
#     email:
#
# search Reg.No and print all details
# check if the regno, exists, if exists replace all the details with the new one.

# %%
studentDeets{}

# %% [markdown]
# QQ: Develop a contact management program where user can add, edit, delete and search contact details using a dictionary. the menu options would facilitate these actions.

# %%
contacts = {}
def addContacts():
    name = input("Enter the contact's name: ")
    number = input("Enter the contact's phone number: ")
    contacts[name] = number

def editContacts():
    name = input("Enter the name of the contact you want to edit: ")
    if name in contacts:
        newNumber = input("Enter a new phone number for : ")
        contacts[name] = newNumber
        print("Contact information has been editted.")
    else:
        print("Not found in contacts.")

def deleteContacts():
    name = input("Enter the Contact name you want to delete: ")
    if name in contacts:
        delNumber =" "
        contacts[name] = delNumber
        print("Contact information has been editted.")
    else:
        print("Not found in contacts.")

# def searchContacts():
#     name = input("Enter the Contact name  you want to search:")
#     for name  in contacts:
#         if found == true 


while True :
    print("%"*30)
    print("-----Welcome to ABC's Contact Management System-----")
    print("MENU")
    print("1. Search for Contact") 
    print("2. Add a Contact")  
    print("3. Delete a contact")
    print("4. Edit a contact")
    print("5. Exit")
    print("%"*30)



    choice = int(input("Enter your choice 1 , 2, 3, 4 ::"))
    print("Your choice is:: ", choice)
    
    if choice == 1:
        name = searchContacts()
        
    elif choice == 2:
        addContacts()

    elif choice == 3:
        deleteContacts()

    elif choice == 4:
        editContacts()

    elif choice == 5:   
        break
       
    else:
        print("Invalid Syntax")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# -----Welcome to ABC's Contact Management System-----
# MENU
# 1. Search for Contact
# 2. Add a Contact
# 3. Delete a contact
# 4. Edit a contact
# 5. Exit
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Your choice is::  2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# -----Welcome to ABC's Contact Management System-----
# MENU
# 1. Search for Contact
# 2. Add a Contact
# 3. Delete a contact
# 4. Edit a contact
# 5. Exit
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Your choice is::  5
